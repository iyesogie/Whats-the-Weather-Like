# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress


from api_keys import weather_api_key
temp_units = "imperial"

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "weather_df.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# define url
query_url = f"http://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&units={temp_units}&q="

# define count of pass throughs
count_one = 0
set_one = 1

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 619

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# set lists for the dataframe
city_two = []
cloudinesses = []
dates = []
humidities = []
lats = []
lngs = []
max_temps = []
wind_speeds = []
countries = []

# set initial count quantities for organization
count_one = 0
set_one = 1

# loops for creating dataframe columns
for city in cities:
    try:
        response = requests.get(query_url + city.replace(" ","&")).json()
        cloudinesses.append(response['clouds']['all'])
        countries.append(response['sys']['country'])
        dates.append(response['dt'])
        humidities.append(response['main']['humidity'])
        lats.append(response['coord']['lat'])
        lngs.append(response['coord']['lon'])
        max_temps.append(response['main']['temp_max'])
        wind_speeds.append(response['wind']['speed'])
        if count_one > 48:
            count_one = 1
            set_one += 1
            city_two.append(city)
        else:
            count_one += 1
            city_two.append(city)
        print(f"Processing Record {count_one} of Set {set_one} | {city}")
    except Exception:
        print("City not found. Skipping...")
print("------------------------------\nData Retrieval Complete\n------------------------------")
# Out:
# Processing Record 1 of Set 1 | nicosia
# Processing Record 2 of Set 1 | honiara
# Processing Record 3 of Set 1 | imbituba
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | zhigansk
# Processing Record 6 of Set 1 | chokurdakh
# Processing Record 7 of Set 1 | bethel
# Processing Record 8 of Set 1 | mar del plata
# Processing Record 9 of Set 1 | provideniya
# Processing Record 10 of Set 1 | yumen
# Processing Record 11 of Set 1 | jamestown
# Processing Record 12 of Set 1 | aransas pass
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | bluff
# Processing Record 15 of Set 1 | alyangula
# Processing Record 16 of Set 1 | saskylakh
# Processing Record 17 of Set 1 | baiyin
# Processing Record 18 of Set 1 | karpogory
# Processing Record 19 of Set 1 | kingaroy
# Processing Record 20 of Set 1 | buraydah
# Processing Record 21 of Set 1 | bengkulu
# Processing Record 22 of Set 1 | tongchuan
# City not found. Skipping...
# Processing Record 23 of Set 1 | pulandian
# Processing Record 24 of Set 1 | norman wells
# Processing Record 25 of Set 1 | mahebourg
# Processing Record 26 of Set 1 | constitucion
# City not found. Skipping...
# Processing Record 27 of Set 1 | viseu
# Processing Record 28 of Set 1 | hobart
# Processing Record 29 of Set 1 | santiago del estero
# Processing Record 30 of Set 1 | kapuskasing
# Processing Record 31 of Set 1 | moussoro
# Processing Record 32 of Set 1 | ribeira brava
# Processing Record 33 of Set 1 | kavieng
# Processing Record 34 of Set 1 | talnakh
# Processing Record 35 of Set 1 | tasiilaq
# Processing Record 36 of Set 1 | victoria
# Processing Record 37 of Set 1 | mazatlan
# Processing Record 38 of Set 1 | cidreira
# Processing Record 39 of Set 1 | lebu
# Processing Record 40 of Set 1 | evensk
# Processing Record 41 of Set 1 | florianopolis
# Processing Record 42 of Set 1 | ponta do sol
# Processing Record 43 of Set 1 | punta arenas
# Processing Record 44 of Set 1 | heilbronn
# Processing Record 45 of Set 1 | shache
# Processing Record 46 of Set 1 | bredasdorp
# Processing Record 47 of Set 1 | sao joao da barra
# Processing Record 48 of Set 1 | sibolga
# Processing Record 49 of Set 1 | qaanaaq
# Processing Record 1 of Set 2 | longyearbyen
# Processing Record 2 of Set 2 | mataura
# Processing Record 3 of Set 2 | sitka
# Processing Record 4 of Set 2 | atuona
# Processing Record 5 of Set 2 | mys shmidta
# Processing Record 6 of Set 2 | nuevo progreso
# Processing Record 7 of Set 2 | carnarvon
# Processing Record 8 of Set 2 | albany
# Processing Record 9 of Set 2 | santa maria
# Processing Record 10 of Set 2 | bend
# Processing Record 11 of Set 2 | avarua
# Processing Record 12 of Set 2 | ancud
# Processing Record 13 of Set 2 | butaritari
# Processing Record 14 of Set 2 | guasdualito
# Processing Record 15 of Set 2 | necochea
# Processing Record 16 of Set 2 | cape town
# Processing Record 17 of Set 2 | borzya
# Processing Record 18 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 19 of Set 2 | georgetown
# Processing Record 20 of Set 2 | yantai
# Processing Record 21 of Set 2 | dingle
# Processing Record 22 of Set 2 | north bend
# Processing Record 23 of Set 2 | sola
# Processing Record 24 of Set 2 | itarema
# Processing Record 25 of Set 2 | maralal
# Processing Record 26 of Set 2 | port-cartier
# Processing Record 27 of Set 2 | arraial do cabo
# Processing Record 28 of Set 2 | nikolskoye
# Processing Record 29 of Set 2 | kenai
# Processing Record 30 of Set 2 | flinders
# Processing Record 31 of Set 2 | moron
# Processing Record 32 of Set 2 | lagoa
# Processing Record 33 of Set 2 | snezhnogorsk
# Processing Record 34 of Set 2 | mbanza-ngungu
# City not found. Skipping...
# Processing Record 35 of Set 2 | kapaa
# Processing Record 36 of Set 2 | saint-philippe
# Processing Record 37 of Set 2 | bourail
# Processing Record 38 of Set 2 | padang
# Processing Record 39 of Set 2 | kyaikkami
# Processing Record 40 of Set 2 | nome
# Processing Record 41 of Set 2 | busselton
# Processing Record 42 of Set 2 | hermanus
# Processing Record 43 of Set 2 | salaga
# City not found. Skipping...
# Processing Record 44 of Set 2 | atlantic city
# Processing Record 45 of Set 2 | chuy
# Processing Record 46 of Set 2 | new norfolk
# Processing Record 47 of Set 2 | tukrah
# Processing Record 48 of Set 2 | mareeba
# Processing Record 49 of Set 2 | yele
# Processing Record 1 of Set 3 | fortuna
# Processing Record 2 of Set 3 | kangaatsiaq
# City not found. Skipping...
# Processing Record 3 of Set 3 | piacabucu
# Processing Record 4 of Set 3 | barrow
# City not found. Skipping...
# Processing Record 5 of Set 3 | port hardy
# Processing Record 6 of Set 3 | bambous virieux
# Processing Record 7 of Set 3 | tuktoyaktuk
# Processing Record 8 of Set 3 | khatanga
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 9 of Set 3 | ilulissat
# City not found. Skipping...
# Processing Record 10 of Set 3 | castro
# Processing Record 11 of Set 3 | souillac
# Processing Record 12 of Set 3 | carira
# City not found. Skipping...
# Processing Record 13 of Set 3 | lodja
# Processing Record 14 of Set 3 | caravelas
# Processing Record 15 of Set 3 | port-gentil
# City not found. Skipping...
# Processing Record 16 of Set 3 | sabang
# Processing Record 17 of Set 3 | mount gambier
# Processing Record 18 of Set 3 | ayan
# Processing Record 19 of Set 3 | upernavik
# Processing Record 20 of Set 3 | peniche
# Processing Record 21 of Set 3 | arman
# Processing Record 22 of Set 3 | ambanja
# Processing Record 23 of Set 3 | tautira
# Processing Record 24 of Set 3 | porto murtinho
# Processing Record 25 of Set 3 | port alfred
# Processing Record 26 of Set 3 | tim
# City not found. Skipping...
# Processing Record 27 of Set 3 | puerto ayora
# Processing Record 28 of Set 3 | mersing
# Processing Record 29 of Set 3 | torbay
# Processing Record 30 of Set 3 | shihezi
# Processing Record 31 of Set 3 | teixeira
# Processing Record 32 of Set 3 | kodiak
# Processing Record 33 of Set 3 | adrar
# Processing Record 34 of Set 3 | anadyr
# Processing Record 35 of Set 3 | leh
# Processing Record 36 of Set 3 | half moon bay
# Processing Record 37 of Set 3 | tazovskiy
# Processing Record 38 of Set 3 | shaunavon
# Processing Record 39 of Set 3 | usinsk
# City not found. Skipping...
# Processing Record 40 of Set 3 | coihaique
# Processing Record 41 of Set 3 | sao filipe
# Processing Record 42 of Set 3 | thompson
# Processing Record 43 of Set 3 | fez
# Processing Record 44 of Set 3 | mecca
# Processing Record 45 of Set 3 | marsa matruh
# Processing Record 46 of Set 3 | tigil
# Processing Record 47 of Set 3 | ponta delgada
# Processing Record 48 of Set 3 | ixtapa
# Processing Record 49 of Set 3 | asyut
# Processing Record 1 of Set 4 | esperance
# Processing Record 2 of Set 4 | ugoofaaru
# Processing Record 3 of Set 4 | katsuura
# Processing Record 4 of Set 4 | beringovskiy
# Processing Record 5 of Set 4 | dikson
# Processing Record 6 of Set 4 | tete
# Processing Record 7 of Set 4 | hilo
# City not found. Skipping...
# Processing Record 8 of Set 4 | krasnotorka
# Processing Record 9 of Set 4 | teguise
# City not found. Skipping...
# Processing Record 10 of Set 4 | hofn
# Processing Record 11 of Set 4 | kanye
# Processing Record 12 of Set 4 | port elizabeth
# Processing Record 13 of Set 4 | pevek
# Processing Record 14 of Set 4 | cururupu
# Processing Record 15 of Set 4 | bagdarin
# Processing Record 16 of Set 4 | college
# Processing Record 17 of Set 4 | asau
# Processing Record 18 of Set 4 | lisakovsk
# Processing Record 19 of Set 4 | vaini
# Processing Record 20 of Set 4 | thiadiaye
# City not found. Skipping...
# Processing Record 21 of Set 4 | klaksvik
# City not found. Skipping...
# Processing Record 22 of Set 4 | asfi
# Processing Record 23 of Set 4 | scarborough
# Processing Record 24 of Set 4 | zyryanka
# Processing Record 25 of Set 4 | broome
# Processing Record 26 of Set 4 | esil
# Processing Record 27 of Set 4 | bow island
# City not found. Skipping...
# Processing Record 28 of Set 4 | agadez
# Processing Record 29 of Set 4 | mehamn
# Processing Record 30 of Set 4 | voh
# Processing Record 31 of Set 4 | dunmore town
# Processing Record 32 of Set 4 | haines junction
# Processing Record 33 of Set 4 | nuevo casas grandes
# Processing Record 34 of Set 4 | nacala
# Processing Record 35 of Set 4 | awbari
# Processing Record 36 of Set 4 | yellowknife
# Processing Record 37 of Set 4 | nanortalik
# Processing Record 38 of Set 4 | saint-augustin
# Processing Record 39 of Set 4 | atar
# Processing Record 40 of Set 4 | kruisfontein
# Processing Record 41 of Set 4 | lata
# Processing Record 42 of Set 4 | brae
# Processing Record 43 of Set 4 | vikramasingapuram
# City not found. Skipping...
# Processing Record 44 of Set 4 | hualmay
# City not found. Skipping...
# Processing Record 45 of Set 4 | punta de piedra
# Processing Record 46 of Set 4 | homer
# Processing Record 47 of Set 4 | sakiai
# Processing Record 48 of Set 4 | uthal
# Processing Record 49 of Set 4 | mildura
# Processing Record 1 of Set 5 | gua
# City not found. Skipping...
# Processing Record 2 of Set 5 | irituia
# Processing Record 3 of Set 5 | goderich
# Processing Record 4 of Set 5 | joensuu
# Processing Record 5 of Set 5 | mahibadhoo
# City not found. Skipping...
# Processing Record 6 of Set 5 | itoman
# City not found. Skipping...
# Processing Record 7 of Set 5 | bathsheba
# Processing Record 8 of Set 5 | nemuro
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 9 of Set 5 | bara
# Processing Record 10 of Set 5 | dongsheng
# Processing Record 11 of Set 5 | champerico
# Processing Record 12 of Set 5 | deniliquin
# City not found. Skipping...
# Processing Record 13 of Set 5 | gushikawa
# Processing Record 14 of Set 5 | khash
# City not found. Skipping...
# Processing Record 15 of Set 5 | alindao
# Processing Record 16 of Set 5 | gibsons
# Processing Record 17 of Set 5 | magadan
# Processing Record 18 of Set 5 | kaitangata
# Processing Record 19 of Set 5 | hithadhoo
# Processing Record 20 of Set 5 | lixourion
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 21 of Set 5 | owen sound
# Processing Record 22 of Set 5 | malanje
# Processing Record 23 of Set 5 | maniitsoq
# Processing Record 24 of Set 5 | zonguldak
# Processing Record 25 of Set 5 | aykhal
# Processing Record 26 of Set 5 | zatoka
# Processing Record 27 of Set 5 | boyolangu
# Processing Record 28 of Set 5 | bandarbeyla
# Processing Record 29 of Set 5 | samarai
# Processing Record 30 of Set 5 | puerto princesa
# Processing Record 31 of Set 5 | trincomalee
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 32 of Set 5 | karratha
# Processing Record 33 of Set 5 | yar-sale
# Processing Record 34 of Set 5 | sierra vista
# Processing Record 35 of Set 5 | cumana
# Processing Record 36 of Set 5 | kumluca
# Processing Record 37 of Set 5 | tarakan
# Processing Record 38 of Set 5 | hasaki
# Processing Record 39 of Set 5 | jamsa
# Processing Record 40 of Set 5 | ribeira grande
# Processing Record 41 of Set 5 | wuzhou
# Processing Record 42 of Set 5 | alofi
# Processing Record 43 of Set 5 | dieppe
# Processing Record 44 of Set 5 | turukhansk
# Processing Record 45 of Set 5 | miyako
# Processing Record 46 of Set 5 | pio ix
# Processing Record 47 of Set 5 | touros
# Processing Record 48 of Set 5 | poso
# Processing Record 49 of Set 5 | sao geraldo do araguaia
# Processing Record 1 of Set 6 | cherskiy
# Processing Record 2 of Set 6 | barra do garcas
# Processing Record 3 of Set 6 | rawson
# Processing Record 4 of Set 6 | vaitape
# Processing Record 5 of Set 6 | labuan
# Processing Record 6 of Set 6 | cabo san lucas
# Processing Record 7 of Set 6 | madang
# Processing Record 8 of Set 6 | kodinsk
# Processing Record 9 of Set 6 | berlevag
# Processing Record 10 of Set 6 | saldanha
# Processing Record 11 of Set 6 | vestmannaeyjar
# City not found. Skipping...
# Processing Record 12 of Set 6 | maumere
# Processing Record 13 of Set 6 | cozumel
# Processing Record 14 of Set 6 | gizo
# Processing Record 15 of Set 6 | port macquarie
# Processing Record 16 of Set 6 | khuzhir
# Processing Record 17 of Set 6 | diapaga
# Processing Record 18 of Set 6 | yueyang
# Processing Record 19 of Set 6 | terenos
# Processing Record 20 of Set 6 | mount isa
# City not found. Skipping...
# Processing Record 21 of Set 6 | faanui
# Processing Record 22 of Set 6 | hirado
# Processing Record 23 of Set 6 | barranca
# Processing Record 24 of Set 6 | lompoc
# City not found. Skipping...
# Processing Record 25 of Set 6 | dolinsk
# Processing Record 26 of Set 6 | soyo
# Processing Record 27 of Set 6 | esso
# Processing Record 28 of Set 6 | tual
# Processing Record 29 of Set 6 | robertson
# Processing Record 30 of Set 6 | miri
# Processing Record 31 of Set 6 | biak
# Processing Record 32 of Set 6 | innisfail
# Processing Record 33 of Set 6 | makakilo city
# Processing Record 34 of Set 6 | carlsbad
# Processing Record 35 of Set 6 | mackay
# Processing Record 36 of Set 6 | praia da vitoria
# Processing Record 37 of Set 6 | ust-kulom
# Processing Record 38 of Set 6 | bosaso
# Processing Record 39 of Set 6 | islamkot
# Processing Record 40 of Set 6 | baker city
# Processing Record 41 of Set 6 | pesaro
# Processing Record 42 of Set 6 | gornopravdinsk
# Processing Record 43 of Set 6 | portland
# Processing Record 44 of Set 6 | kurumkan
# Processing Record 45 of Set 6 | kutum
# Processing Record 46 of Set 6 | alghero
# Processing Record 47 of Set 6 | leningradskiy
# Processing Record 48 of Set 6 | bonthe
# Processing Record 49 of Set 6 | pandan
# Processing Record 1 of Set 7 | bubaque
# Processing Record 2 of Set 7 | cabatuan
# Processing Record 3 of Set 7 | matara
# Processing Record 4 of Set 7 | shingu
# Processing Record 5 of Set 7 | jinchang
# City not found. Skipping...
# Processing Record 6 of Set 7 | san andres
# Processing Record 7 of Set 7 | haverfordwest
# Processing Record 8 of Set 7 | inhambane
# Processing Record 9 of Set 7 | tilichiki
# Processing Record 10 of Set 7 | kloulklubed
# Processing Record 11 of Set 7 | torit
# Processing Record 12 of Set 7 | roma
# Processing Record 13 of Set 7 | bardiyah
# Processing Record 14 of Set 7 | aklavik
# Processing Record 15 of Set 7 | carupano
# Processing Record 16 of Set 7 | meulaboh
# Processing Record 17 of Set 7 | cayenne
# Processing Record 18 of Set 7 | east london
# Processing Record 19 of Set 7 | palmer
# Processing Record 20 of Set 7 | luanda
# City not found. Skipping...
# Processing Record 21 of Set 7 | katangli
# Processing Record 22 of Set 7 | geraldton
# City not found. Skipping...
# Processing Record 23 of Set 7 | luderitz
# Processing Record 24 of Set 7 | lorengau
# Processing Record 25 of Set 7 | hudson bay
# Processing Record 26 of Set 7 | kahului
# Processing Record 27 of Set 7 | whitecourt
# Processing Record 28 of Set 7 | kattivakkam
# City not found. Skipping...
# Processing Record 29 of Set 7 | kadoma
# Processing Record 30 of Set 7 | pitimbu
# Processing Record 31 of Set 7 | ntcheu
# City not found. Skipping...
# Processing Record 32 of Set 7 | manzanillo
# Processing Record 33 of Set 7 | san-pedro
# Processing Record 34 of Set 7 | sinnamary
# Processing Record 35 of Set 7 | port lincoln
# Processing Record 36 of Set 7 | pirgos
# Processing Record 37 of Set 7 | husavik
# Processing Record 38 of Set 7 | ceyhan
# Processing Record 39 of Set 7 | cartagena del chaira
# Processing Record 40 of Set 7 | wamba
# City not found. Skipping...
# Processing Record 41 of Set 7 | sorong
# City not found. Skipping...
# Processing Record 42 of Set 7 | faya
# Processing Record 43 of Set 7 | clyde river
# Processing Record 44 of Set 7 | vostochnyy
# Processing Record 45 of Set 7 | salalah
# Processing Record 46 of Set 7 | anloga
# Processing Record 47 of Set 7 | narsaq
# Processing Record 48 of Set 7 | vila velha
# Processing Record 49 of Set 7 | kamen-na-obi
# Processing Record 1 of Set 8 | verkhoyansk
# Processing Record 2 of Set 8 | trapani
# Processing Record 3 of Set 8 | grand river south east
# Processing Record 4 of Set 8 | beloha
# Processing Record 5 of Set 8 | port blair
# Processing Record 6 of Set 8 | ust-kuyga
# Processing Record 7 of Set 8 | hami
# Processing Record 8 of Set 8 | svetlogorsk
# Processing Record 9 of Set 8 | komsomolskiy
# Processing Record 10 of Set 8 | pisco
# City not found. Skipping...
# Processing Record 11 of Set 8 | payakumbuh
# City not found. Skipping...
# Processing Record 12 of Set 8 | murchison
# Processing Record 13 of Set 8 | erenhot
# Processing Record 14 of Set 8 | nishihara
# Processing Record 15 of Set 8 | prince rupert
# Processing Record 16 of Set 8 | darlowo
# Processing Record 17 of Set 8 | san quintin
# Processing Record 18 of Set 8 | tiksi
# Processing Record 19 of Set 8 | vostok
# City not found. Skipping...
# Processing Record 20 of Set 8 | smithers
# Processing Record 21 of Set 8 | villazon
# City not found. Skipping...
# Processing Record 22 of Set 8 | svidnik
# Processing Record 23 of Set 8 | nouadhibou
# Processing Record 24 of Set 8 | oktyabrskoye
# City not found. Skipping...
# Processing Record 25 of Set 8 | young
# Processing Record 26 of Set 8 | kharan
# Processing Record 27 of Set 8 | wad madani
# Processing Record 28 of Set 8 | puerto escondido
# City not found. Skipping...
# Processing Record 29 of Set 8 | zhuhai
# City not found. Skipping...
# Processing Record 30 of Set 8 | tam ky
# Processing Record 31 of Set 8 | businga
# Processing Record 32 of Set 8 | viedma
# Processing Record 33 of Set 8 | haapiti
# Processing Record 34 of Set 8 | acapulco
# Processing Record 35 of Set 8 | iqaluit
# Processing Record 36 of Set 8 | yarada
# Processing Record 37 of Set 8 | severo-kurilsk
# Processing Record 38 of Set 8 | jacareacanga
# Processing Record 39 of Set 8 | sabha
# Processing Record 40 of Set 8 | abu dhabi
# Processing Record 41 of Set 8 | derzhavinsk
# Processing Record 42 of Set 8 | grand gaube
# Processing Record 43 of Set 8 | ituverava
# Processing Record 44 of Set 8 | mugur-aksy
# Processing Record 45 of Set 8 | mackenzie
# Processing Record 46 of Set 8 | lavrentiya
# Processing Record 47 of Set 8 | linxia
# Processing Record 48 of Set 8 | tambacounda
# Processing Record 49 of Set 8 | curumani
# Processing Record 1 of Set 9 | balaipungut
# Processing Record 2 of Set 9 | yining
# Processing Record 3 of Set 9 | sambava
# City not found. Skipping...
# Processing Record 4 of Set 9 | udimskiy
# Processing Record 5 of Set 9 | ramanathapuram
# Processing Record 6 of Set 9 | tevriz
# Processing Record 7 of Set 9 | podyuga
# Processing Record 8 of Set 9 | dongkan
# Processing Record 9 of Set 9 | muros
# Processing Record 10 of Set 9 | gunjur
# Processing Record 11 of Set 9 | cairns
# Processing Record 12 of Set 9 | laguna
# Processing Record 13 of Set 9 | aktau
# Processing Record 14 of Set 9 | gravelbourg
# Processing Record 15 of Set 9 | aljezur
# Processing Record 16 of Set 9 | surgut
# Processing Record 17 of Set 9 | hamilton
# Processing Record 18 of Set 9 | nuuk
# Processing Record 19 of Set 9 | kokopo
# Processing Record 20 of Set 9 | fare
# Processing Record 21 of Set 9 | doba
# Processing Record 22 of Set 9 | kabare
# Processing Record 23 of Set 9 | rundu
# Processing Record 24 of Set 9 | santa maria del oro
# Processing Record 25 of Set 9 | teterow
# City not found. Skipping...
# Processing Record 26 of Set 9 | antalaha
# Processing Record 27 of Set 9 | moscow
# Processing Record 28 of Set 9 | port moresby
# Processing Record 29 of Set 9 | rio grande
# City not found. Skipping...
# Processing Record 30 of Set 9 | ogaminana
# Processing Record 31 of Set 9 | huadian
# Processing Record 32 of Set 9 | sisimiut
# City not found. Skipping...
# Processing Record 33 of Set 9 | les cayes
# Processing Record 34 of Set 9 | toora-khem
# Processing Record 35 of Set 9 | riyadh
# Processing Record 36 of Set 9 | mikun
# City not found. Skipping...
# Processing Record 37 of Set 9 | cartagena
# Processing Record 38 of Set 9 | kavaratti
# City not found. Skipping...
# Processing Record 39 of Set 9 | taldan
# Processing Record 40 of Set 9 | huarmey
# Processing Record 41 of Set 9 | havre-saint-pierre
# Processing Record 42 of Set 9 | gueret
# Processing Record 43 of Set 9 | vanderhoof
# Processing Record 44 of Set 9 | zyryanskoye
# Processing Record 45 of Set 9 | pinega
# Processing Record 46 of Set 9 | tura
# Processing Record 47 of Set 9 | gayny
# Processing Record 48 of Set 9 | airai
# Processing Record 49 of Set 9 | mayumba
# Processing Record 1 of Set 10 | aduturai
# Processing Record 2 of Set 10 | taltal
# Processing Record 3 of Set 10 | bodden town
# Processing Record 4 of Set 10 | tiruchchendur
# City not found. Skipping...
# Processing Record 5 of Set 10 | talaya
# Processing Record 6 of Set 10 | quelimane
# Processing Record 7 of Set 10 | cockburn town
# Processing Record 8 of Set 10 | putina
# Processing Record 9 of Set 10 | bideford
# City not found. Skipping...
# Processing Record 10 of Set 10 | chaman
# Processing Record 11 of Set 10 | ibotirama
# Processing Record 12 of Set 10 | tottori
# Processing Record 13 of Set 10 | sunyani
# Processing Record 14 of Set 10 | carballo
# Processing Record 15 of Set 10 | namibe
# Processing Record 16 of Set 10 | bonavista
# Processing Record 17 of Set 10 | eureka
# Processing Record 18 of Set 10 | taubate
# Processing Record 19 of Set 10 | tuatapere
# Processing Record 20 of Set 10 | dukat
# Processing Record 21 of Set 10 | carutapera
# Processing Record 22 of Set 10 | korla
# Processing Record 23 of Set 10 | chapais
# Processing Record 24 of Set 10 | tocopilla
# City not found. Skipping...
# Processing Record 25 of Set 10 | berdyaush
# Processing Record 26 of Set 10 | kanniyakumari
# Processing Record 27 of Set 10 | matagami
# Processing Record 28 of Set 10 | ust-maya
# Processing Record 29 of Set 10 | pangody
# City not found. Skipping...
# Processing Record 30 of Set 10 | monticello
# Processing Record 31 of Set 10 | vila franca do campo
# Processing Record 32 of Set 10 | beyla
# City not found. Skipping...
# Processing Record 33 of Set 10 | machico
# Processing Record 34 of Set 10 | kamaishi
# City not found. Skipping...
# Processing Record 35 of Set 10 | andenes
# Processing Record 36 of Set 10 | kidal
# Processing Record 37 of Set 10 | boralday
# Processing Record 38 of Set 10 | digras
# Processing Record 39 of Set 10 | empalme
# Processing Record 40 of Set 10 | thinadhoo
# Processing Record 41 of Set 10 | guerrero negro
# Processing Record 42 of Set 10 | tortoli
# Processing Record 43 of Set 10 | deputatskiy
# Processing Record 44 of Set 10 | gidam
# Processing Record 45 of Set 10 | xiuyan
# Processing Record 46 of Set 10 | lakatoro
# Processing Record 47 of Set 10 | tuy hoa
# Processing Record 48 of Set 10 | myanaung
# Processing Record 49 of Set 10 | ngunguru
# Processing Record 1 of Set 11 | trinidad
# Processing Record 2 of Set 11 | hervey bay
# Processing Record 3 of Set 11 | tecoanapa
# Processing Record 4 of Set 11 | sabya
# Processing Record 5 of Set 11 | songjianghe
# Processing Record 6 of Set 11 | codrington
# Processing Record 7 of Set 11 | abu samrah
# Processing Record 8 of Set 11 | inuvik
# Processing Record 9 of Set 11 | chicama
# Processing Record 10 of Set 11 | yaan
# City not found. Skipping...
# Processing Record 11 of Set 11 | cedral
# Processing Record 12 of Set 11 | porto novo
# Processing Record 13 of Set 11 | atambua
# Processing Record 14 of Set 11 | nador
# Processing Record 15 of Set 11 | yerbogachen
# Processing Record 16 of Set 11 | afsin
# Processing Record 17 of Set 11 | gouyave
# Processing Record 18 of Set 11 | tarrafal
# Processing Record 19 of Set 11 | naze
# Processing Record 20 of Set 11 | konstantinovka
# Processing Record 21 of Set 11 | okhotsk
# Processing Record 22 of Set 11 | sabzevar
# Processing Record 23 of Set 11 | marshall
# Processing Record 24 of Set 11 | qaqortoq
# Processing Record 25 of Set 11 | mahajanga
# Processing Record 26 of Set 11 | najran
# City not found. Skipping...
# Processing Record 27 of Set 11 | isangel
# Processing Record 28 of Set 11 | nizhniy baskunchak
# Processing Record 29 of Set 11 | mpulungu
# Processing Record 30 of Set 11 | soligalich
# Processing Record 31 of Set 11 | bocaiuva
# Processing Record 32 of Set 11 | sao miguel do oeste
# Processing Record 33 of Set 11 | amapa
# Processing Record 34 of Set 11 | malatya
# Processing Record 35 of Set 11 | whitianga
# Processing Record 36 of Set 11 | ponot
# Processing Record 37 of Set 11 | talakan
# City not found. Skipping...
# Processing Record 38 of Set 11 | svetlaya
# Processing Record 39 of Set 11 | hun
# Processing Record 40 of Set 11 | orotina
# Processing Record 41 of Set 11 | sur
# Processing Record 42 of Set 11 | basco
# Processing Record 43 of Set 11 | hay river
# Processing Record 44 of Set 11 | veraval
# Processing Record 45 of Set 11 | omsukchan
# Processing Record 46 of Set 11 | trindade
# Processing Record 47 of Set 11 | kamenka
# Processing Record 48 of Set 11 | qasigiannguit
# City not found. Skipping...
# Processing Record 49 of Set 11 | sovetskiy
# Processing Record 1 of Set 12 | kawalu
# Processing Record 2 of Set 12 | ottawa
# Processing Record 3 of Set 12 | coahuayana
# Processing Record 4 of Set 12 | verkhovazhye
# Processing Record 5 of Set 12 | roald
# Processing Record 6 of Set 12 | belmonte
# Processing Record 7 of Set 12 | maturin
# Processing Record 8 of Set 12 | olinda
# Processing Record 9 of Set 12 | san patricio
# Processing Record 10 of Set 12 | kachug
# Processing Record 11 of Set 12 | pacific grove
# Processing Record 12 of Set 12 | newport
# Processing Record 13 of Set 12 | trairi
# Processing Record 14 of Set 12 | yulara
# Processing Record 15 of Set 12 | port augusta
# Processing Record 16 of Set 12 | pundaguitan
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# create a dictionary for establishing dataframe
weather_dict = {
    "City":city_two,
    "Cloudiness":cloudinesses,
    "Country":countries,
    "Date":dates,
    "Humidity":humidities,
    "Lat":lats,
    "Lng":lngs,
    "Max Temp":max_temps,
    "Wind Speed":wind_speeds
}

# establish dataframe
weather_dataframe = pd.DataFrame(weather_dict)

# show the top of the dataframe
weather_dataframe.head()
# Out:
#        City  Cloudiness Country        Date  Humidity      Lat       Lng  \
# 0   nicosia          20      CY  1624721686        21  35.1667   33.3667
# 1   honiara         100      SB  1624721175        90  -9.4333  159.9500
# 2  imbituba          76      BR  1624721687        70 -28.2400  -48.6703
# 3   rikitea           1      PF  1624721687        76 -23.1203 -134.9692
# 4  zhigansk          99      RU  1624721687        81  66.7697  123.3711
#
#    Max Temp  Wind Speed
# 0     96.49       12.66
# 1     76.75        8.46
# 2     67.89       15.48
# 3     73.76        7.40
# 4     61.59        9.06

# %%
# output data to csv
weather_dataframe.to_csv(output_data_file)

weather_dataframe.count()

weather_dataframe.head()
# Out:
#        City  Cloudiness Country        Date  Humidity      Lat       Lng  \
# 0   nicosia          20      CY  1624721686        21  35.1667   33.3667
# 1   honiara         100      SB  1624721175        90  -9.4333  159.9500
# 2  imbituba          76      BR  1624721687        70 -28.2400  -48.6703
# 3   rikitea           1      PF  1624721687        76 -23.1203 -134.9692
# 4  zhigansk          99      RU  1624721687        81  66.7697  123.3711
#
#    Max Temp  Wind Speed
# 0     96.49       12.66
# 1     76.75        8.46
# 2     67.89       15.48
# 3     73.76        7.40
# 4     61.59        9.06

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(weather_dataframe["Lat"],weather_dataframe["Max Temp"],edgecolors="black",facecolors="skyblue")
plt.title("City Latitude vs. Max Temperature (01/07/19)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("fig1.png")
plt.show()

# %% [markdown]
# This plot is looking at the relationship between latitude and temperature

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(weather_dataframe["Lat"],weather_dataframe["Humidity"],edgecolors="black",facecolors="skyblue")
plt.title("City Latitude vs. Humidity (01/07/19)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.ylim(15,105)
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("fig2.png")
plt.show()

# %% [markdown]
# This plot is looking at the relationship between latitude and humidity

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_dataframe["Lat"],weather_dataframe["Cloudiness"],edgecolors="black",facecolors="skyblue")
plt.title("City Latitude vs. Cloudiness (01/07/19)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("fig3.png")
plt.show()

# %% [markdown]
# This plot is looking at the relationship between latitude and cloudiness.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_dataframe["Lat"],weather_dataframe["Wind Speed"],edgecolors="black",facecolors="skyblue")
plt.title("City Latitude vs. Wind Speed (01/07/19)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.ylim(-2,34)
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("fig4.png")
plt.show()

# %% [markdown]
# This plot is looking at the relationship between latitude and wind speed

# %% [markdown]
# ## Linear Regression

# %%
#takes in as arguments a DataFrame (df), the x-axis String column name (x_Col), and the y-axis String column name (y_Col)
#plots a scatter plot with the df[x_Col] on the x-axis and the df[y_Col] data on the y-axis, and the linear regression line
#prints information about the best fit line from the linear regression
#returns the axes object for the plot, so more changes can be made later if necessary
def makeLinRegression(df, x_Col, y_Col):
    #first, perform the linear regression on the data
    (regr_slope, regr_intercept, regr_r_val, _, _) = linregress(df[x_Col], 
                                                           df[y_Col])
    #setup the linear regression line x and y axes data points
    regr_line_x = np.array([a for a in range(int(min(df[x_Col].values)), int(max(df[x_Col].values)+1))])
    regr_line_y = regr_slope * regr_line_x + regr_intercept

    #plot the scatterplot with the raw data first!
    df_axes = df.plot(kind="scatter", x=x_Col, y=y_Col, 
                      title="{} vs. {} ({})"
                        .format(y_Col, x_Col, remaining_cities["Date"].iloc[0].split(",")[0]))

    #add the best fit lines to the plot as a solid red line
    df_axes.plot(regr_line_x, regr_line_y, 'r')

    #output best-fit line information
    print("The equation of the best-fit linear regression line for this chart is y={:.2f}x+{:.2f}"
          .format(regr_slope, regr_intercept))
    print("The r-squared correlation coefficient for this line is {:.2f}".format(regr_r_val))
                  
    #return the axes object for the plots, in case any changes need to be made
    return df_axes

# %%
# Create Northern and Southern Hemisphere DataFrames

#first, get a subset of all the cities that are on or north of the equator for the Northern Hemisphere DataFrame
northern_hemisphere = weather_dataframe.loc[weather_dataframe["Lat"] >= 0]
northern_cities_count = len(northern_hemisphere)


#first, get a subset of all the cities that are south of the equator for the Southern Hemisphere DataFrame
southern_hemisphere = weather_dataframe.loc[weather_dataframe["Lat"] < 0]
southern_cities_count = len(southern_hemisphere)

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
(n_temp_slope, n_temp_intercept, n_temp_r_val, _, _) = linregress(northern_hemisphere["Lat"], 
                                                           northern_hemisphere["Max Temp"])

regr_line_x = np.array([a for a in range(80)])
regr_line_y = n_temp_slope * regr_line_x + n_temp_intercept

n_temp_axes = northern_hemisphere.plot(kind="scatter", x="Lat", 
                                       y="Max Temp", 
                                       title="Max Temp vs. Lat ({})")
n_temp_axes.plot(regr_line_x, regr_line_y, 'r')

print("The equation of the best-fit linear regression line for this chart is y={:.2f}x+{:.2f}"
      .format(n_temp_slope, n_temp_intercept))
print("The r-squared correlation coefficient for this line is {:.2f}".format(n_temp_r_val))
n_temp_axes.get_figure().savefig("Temp_vs_Latitude_N_Hemisphere.png")
# Out:
# The equation of the best-fit linear regression line for this chart is y=-0.52x+93.27
# The r-squared correlation coefficient for this line is -0.69

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
(s_temp_slope, s_temp_intercept, s_temp_r_val, _, _) = linregress(southern_hemisphere["Lat"], 
                                                           southern_hemisphere["Max Temp"])

regr_line_x = np.array([a for a in range(80)])
regr_line_y = s_temp_slope * regr_line_x + s_temp_intercept

s_temp_axes = northern_hemisphere.plot(kind="scatter", x="Lat", 
                                       y="Max Temp", 
                                       title="Max Temp vs. Lat ({})")
s_temp_axes.plot(regr_line_x, regr_line_y, 'r')

print("The equation of the best-fit linear regression line for this chart is y={:.2f}x+{:.2f}"
      .format(s_temp_slope, s_temp_intercept))
print("The r-squared correlation coefficient for this line is {:.2f}".format(n_temp_r_val))
s_temp_axes.get_figure().savefig("Temp_vs_Latitude_S_Hemisphere.png")
# Out:
# The equation of the best-fit linear regression line for this chart is y=0.85x+84.86
# The r-squared correlation coefficient for this line is -0.69

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
(n_humidity_slope, n_humidity_intercept, n_humidity_r_val, _, _) = linregress(northern_hemisphere["Lat"], 
                                                           northern_hemisphere["Humidity"])

regr_line_x = np.array([a for a in range(80)])
regr_line_y = n_humidity_slope * regr_line_x + n_humidity_intercept

n_humidity_axes = northern_hemisphere.plot(kind="scatter", x="Lat", 
                                       y="Humidity", 
                                       title="Humidity vs. Lat ({})")
n_humidity_axes.plot(regr_line_x, regr_line_y, 'r')

print("The equation of the best-fit linear regression line for this chart is y={:.2f}x+{:.2f}"
      .format(n_humidity_slope, n_humidity_intercept))
print("The r-squared correlation coefficient for this line is {:.2f}".format(n_humidity_r_val))
n_humidity_axes.get_figure().savefig("Humidity_vs_Latitude_N_Hemisphere.png")
# Out:
# The equation of the best-fit linear regression line for this chart is y=0.09x+63.48
# The r-squared correlation coefficient for this line is 0.08

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
(s_humidity_slope, s_humidity_intercept, s_humidity_r_val, _, _) = linregress(southern_hemisphere["Lat"], 
                                                           southern_hemisphere["Humidity"])

regr_line_x = np.array([a for a in range(80)])
regr_line_y = s_humidity_slope * regr_line_x + s_humidity_intercept

s_humidity_axes = southern_hemisphere.plot(kind="scatter", x="Lat", 
                                       y="Humidity", 
                                       title="Humidity vs. Lat ({})")
s_humidity_axes.plot(regr_line_x, regr_line_y, 'r')

print("The equation of the best-fit linear regression line for this chart is y={:.2f}x+{:.2f}"
      .format(s_humidity_slope, s_humidity_intercept))
print("The r-squared correlation coefficient for this line is {:.2f}".format(s_humidity_r_val))
s_humidity_axes.get_figure().savefig("Humidity_vs_Latitude_S_Hemisphere.png")
# Out:
# The equation of the best-fit linear regression line for this chart is y=-0.28x+62.84
# The r-squared correlation coefficient for this line is -0.18

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
(n_Cloudiness_slope, n_Cloudiness_intercept, n_Cloudiness_r_val, _, _) = linregress(northern_hemisphere["Lat"], 
                                                           northern_hemisphere["Cloudiness"])

regr_line_x = np.array([a for a in range(80)])
regr_line_y = n_Cloudiness_slope * regr_line_x + n_Cloudiness_intercept

n_Cloudiness_axes = northern_hemisphere.plot(kind="scatter", x="Lat", 
                                       y="Cloudiness", 
                                       title="Cloudiness vs. Lat ({})")
n_Cloudiness_axes.plot(regr_line_x, regr_line_y, 'r')

print("The equation of the best-fit linear regression line for this chart is y={:.2f}x+{:.2f}"
      .format(n_Cloudiness_slope, n_Cloudiness_intercept))
print("The r-squared correlation coefficient for this line is {:.2f}".format(n_humidity_r_val))
n_Cloudiness_axes.get_figure().savefig("Cloudiness_vs_Latitude_N_Hemisphere.png")
# Out:
# The equation of the best-fit linear regression line for this chart is y=-0.00x+60.38
# The r-squared correlation coefficient for this line is 0.08

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
(s_Cloudiness_slope, s_Cloudiness_intercept, s_Cloudiness_r_val, _, _) = linregress(southern_hemisphere["Lat"], 
                                                           southern_hemisphere["Cloudiness"])

regr_line_x = np.array([a for a in range(80)])
regr_line_y = s_Cloudiness_slope * regr_line_x + s_Cloudiness_intercept

s_Cloudiness_axes = southern_hemisphere.plot(kind="scatter", x="Lat", 
                                       y="Cloudiness", 
                                       title="Cloudiness  vs. Lat ({})")
s_Cloudiness_axes.plot(regr_line_x, regr_line_y, 'r')

print("The equation of the best-fit linear regression line for this chart is y={:.2f}x+{:.2f}"
      .format(s_Cloudiness_slope, s_Cloudiness_intercept))
print("The r-squared correlation coefficient for this line is {:.2f}".format(s_humidity_r_val))
s_humidity_axes.get_figure().savefig("Cloudiness_vs_Latitude_S_Hemisphere.png")
# Out:
# The equation of the best-fit linear regression line for this chart is y=0.02x+48.14
# The r-squared correlation coefficient for this line is -0.18

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
(n_Wind_Speed_slope, n_Wind_Speed_intercept, n_Wind_Speed_r_val, _, _) = linregress(northern_hemisphere["Lat"], 
                                                           northern_hemisphere["Wind Speed"])

regr_line_x = np.array([a for a in range(80)])
regr_line_y = n_Wind_Speed_slope * regr_line_x + n_Wind_Speed_intercept

n_Wind_Speed_axes = northern_hemisphere.plot(kind="scatter", x="Lat", 
                                       y="Wind Speed", 
                                       title="Wind Speed vs. Lat ({})")
n_Wind_Speed_axes.plot(regr_line_x, regr_line_y, 'r')

print("The equation of the best-fit linear regression line for this chart is y={:.2f}x+{:.2f}"
      .format(n_Wind_Speed_slope, n_Wind_Speed_intercept))
print("The r-squared correlation coefficient for this line is {:.2f}".format(n_humidity_r_val))
n_Cloudiness_axes.get_figure().savefig("Wind Speed_vs_Latitude_N_Hemisphere.png")
# Out:
# The equation of the best-fit linear regression line for this chart is y=-0.03x+8.65
# The r-squared correlation coefficient for this line is 0.08

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
(s_Wind_Speed_slope, s_Wind_Speed_intercept, s_Wind_Speed_r_val, _, _) = linregress(southern_hemisphere["Lat"], 
                                                           southern_hemisphere["Wind Speed"])

regr_line_x = np.array([a for a in range(80)])
regr_line_y = s_Wind_Speed_slope * regr_line_x + s_Wind_Speed_intercept

s_Wind_Speed_axes = southern_hemisphere.plot(kind="scatter", x="Lat", 
                                       y="Wind Speed", 
                                       title="Wind Speed  vs. Lat ({})")
s_Wind_Speed_axes.plot(regr_line_x, regr_line_y, 'r')

print("The equation of the best-fit linear regression line for this chart is y={:.2f}x+{:.2f}"
      .format(s_Wind_Speed_slope, s_Wind_Speed_intercept))
print("The r-squared correlation coefficient for this line is {:.2f}".format(s_humidity_r_val))
s_humidity_axes.get_figure().savefig("Wind_Speed_vs_Latitude_S_Hemisphere.png")
# Out:
# The equation of the best-fit linear regression line for this chart is y=-0.08x+6.77
# The r-squared correlation coefficient for this line is -0.18
